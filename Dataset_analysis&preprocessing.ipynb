# %% [markdown]
# <a href="https://colab.research.google.com/github/riuls/an2dl_challenge_2/blob/luis/Dataset_analysis%26preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/Deep Learning Challenge/an2dl_challenge_2
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/Deep Learning Challenge/an2dl_challenge_2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import seaborn as sns
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
tdata = np.load('training_data.npy')
cat = np.load('categories.npy')
valid = np.load('valid_periods.npy')
df_tdata = pd.DataFrame(data=tdata)
df_cat = pd.DataFrame(data = cat)
df_valid = pd.DataFrame(data = valid)

# %%
df_tdata.describe()
# Out:
#                0             1             2             3             4     \
# count  48000.000000  48000.000000  48000.000000  48000.000000  48000.000000
# mean       0.000004      0.000004      0.000004      0.000003      0.000003
# std        0.000837      0.000813      0.000781      0.000760      0.000757
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        0.183319      0.178061      0.171051      0.166542      0.165793
#
#                5             6             7             8             9     \
# count  48000.000000  48000.000000  48000.000000  48000.000000  48000.000000
# mean       0.000003      0.000003      0.000003      0.000003      0.000003
# ...

# %%
df_cat.describe()
# Out:
#             0
# count   48000
# unique      6
# top         B
# freq    10987

# %%
df_cat.columns = ['category']
df_cat.head()
# Out:
#   category
# 0        D
# 1        D
# 2        D
# 3        D
# 4        D

# %%
df_cat['category'] = pd.Categorical(df_cat['category']).codes
df_cat.head()
cat = df_cat.values
print(pd.unique(df_cat['category']))
# Out:
# [3 4 0 2 1 5]

# %%
# Inspect activities timestamps
plt.figure(figsize=(17,5))
sns.countplot(x = 'category', data = df_cat, order = df_cat.category.value_counts().index)
plt.title('Category count')
plt.show()

# %% [markdown]
# There is an unbalance in the classes and 'F' class appears to be the most unbalanced. Furthermore if we divide the samples in training and test set the result is that some labels are not represented in the test set

# %%
train_size = int(len(df_cat) * 0.8)
test_size = len(df_cat) - train_size
train = df_cat[0:train_size]
test = df_cat[train_size:len(df_cat)]

# Inspect activities timestamps
plt.figure(figsize=(17,5))
sns.countplot(x = 'category', data = train, order = train.category.value_counts().index)
plt.title('Category count')
plt.show()

plt.figure(figsize=(17,5))
sns.countplot(x = 'category', data = test, order = test.category.value_counts().index)
plt.title('Category count')
plt.show()

# %%
df_data = df_tdata.loc[9000,:]
df_data.describe()
# Out:
# count    2776.000000
# mean        0.008783
# std         0.074257
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: 9000, dtype: float64

# %% [markdown]
# Training data values appear to be null until a certain time coordinate

# %%
axis = df_data.plot(subplots=True, figsize=(17, 9), title='sample_values')
for ax in axis:
  ax.legend(loc='lower right')

# %%
X = np.reshape(tdata, (48000, 1, 2776))
y = np.reshape(cat, (48000, 1))

# %%
df_tdata.shape
#df_cat.shape
# Out:
# (48000, 2776)

# %%
X_train_size = int(len(tdata) * 0.8)
X_test_size = len(tdata) - X_train_size
y_test_size = len(cat) - X_train_size
X_train, X_test, y_train, y_test = tdata[0:X_train_size, :], tdata[X_train_size:len(tdata), :], cat[0:X_train_size], cat[X_train_size:len(tdata)]
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((38400, 2776), (9600, 2776), (38400, 1), (9600, 1))

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((38400, 2776), (38400, 5), (9600, 2776), (9600, 6))
